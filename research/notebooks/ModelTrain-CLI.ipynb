# %%
# Clone the repo
# !git clone https://github.com/atikul-islam-sajib/U-Net-MultiClass.git
# Out:
# Cloning into 'U-Net-MultiClass'...
# remote: Enumerating objects: 6933, done.
# remote: Counting objects: 100% (481/481), done.[K
# remote: Compressing objects: 100% (346/346), done.
# remote: Total 6933 (delta 148), reused 447 (delta 115), pack-reused 6452
# Receiving objects: 100% (6933/6933), 140.80 MiB | 4.90 MiB/s, done.
# Resolving deltas: 100% (178/178), done.

# %%
# Change the directory to the cloned repo
# %cd U-Net-MultiClass
# Out:
# /Users/shahmuhammadraditrahman/Desktop/model/U-Net-MultiClass

# %%
# Install the requirements
# !pip install -r requirements.txt

# %%
# Run the CLI arguments
# !python src/cli.py --train

# %%
# Do the training with respect to desired arguments
# !python src/cli.py --image_path /cell.zip --image_size 128 --batch_size 4 --split_ratio 0.30 --epochs 10 --lr 0.01 --smooth_value 0.01 --device mps --display True --train
# Out:
# ...
# 100%|███████████████████████████████████████████| 10/10 [10:04<00:00, 60.47s/it]

# %%
# Do the test and check the performance
# !python src/cli.py --device mps --test
# Out:
# Figure(4000x3500)

# %%
from IPython.display import Image

# %%
Image("./outputs/test_images/result.png")
